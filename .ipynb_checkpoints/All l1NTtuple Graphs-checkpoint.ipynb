# %%
import uproot
filename = "l1TNtuple-Htt.root"
treename = "l1TNtupleProducer"
file = uproot.open(filename)
tree = file["l1NtupleProducer/genParticleTree"]

import hist

# %%
tree.keys()
# Out:
# ['run',
#  'lumi',
#  'event',
#  'mom_Pdg',
#  'mom_Mass',
#  'mom_Pt',
#  'mom_Eta',
#  'mom_Phi',
#  'momVis_Mass',
#  'momVis_Pt',
#  'momVis_Eta',
#  'momVis_Phi',
#  'genTauPt_1',
#  'genTauEta_1',
#  'genTauPhi_1',
#  'genTauM_1',
#  'genTauPt_2',
#  'genTauEta_2',
#  'genTauPhi_2',
#  'genTauM_2',
#  'genTauLegDR',
#  'genPt_1',
#  'genEta_1',
#  'genPhi_1',
#  'genM_1',
#  'genPdg_1',
#  'genPt_2',
#  'genEta_2',
#  'genPhi_2',
#  'genM_2',
#  'genPdg_2',
#  'genLegDR',
#  'genLegDEta',
#  'genLegDPhi',
#  'nTauE',
#  'nTauMu',
#  'nTauH',
#  'nGenCandsFound',
#  'recoPt_1',
#  'recoEta_1',
#  'recoPhi_1',
#  'recoM_1',
#  'recoPt_2',
#  'recoEta_2',
#  'recoPhi_2',
#  'recoM_2',
#  'recoDiCandPt',
#  'recoDiCandM',
#  'recoDR',
#  'recoDEta',
#  'recoDPhi',
#  'l1Pt',
#  'l1Eta',
#  'l1Phi',
#  'l1BoostedPt',
#  'l1BoostedEta',
#  'l1BoostedPhi']

# %%
run=tree["run"]
array1=run.array()
h = hist.Hist(hist.axis.Regular(5, 0, 50, label="Run"))
h.fill(array1)
h.plot()
# Out:
# [StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x7ff4f7024ee0>, errorbar=<ErrorbarContainer object of 3 artists>, legend_artist=<ErrorbarContainer object of 3 artists>)]

# %%
 lumi= tree["lumi"]
array1= lumi.array()
h = hist.Hist(hist.axis.Regular(20, 0, 100, label="Lumi"))
h.fill(array1)
h.plot()
# Out:
# [StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x7ff4f70b8190>, errorbar=<ErrorbarContainer object of 3 artists>, legend_artist=<ErrorbarContainer object of 3 artists>)]

# %%
 event= tree["event"]
array1= event.array()
h = hist.Hist(hist.axis.Regular(40, 0, 10000, label="Event"))
h.fill(array1)
h.plot()
# Out:
# [StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x7ff4f7127e20>, errorbar=<ErrorbarContainer object of 3 artists>, legend_artist=<ErrorbarContainer object of 3 artists>)]

# %%
 = tree[""]
array1= .array()
h = hist.Hist(hist.axis.Regular(40, 0, 1000, label="Pt"))
h.fill(array1)
h.plot()

# %%
 mom_Pdg= tree["mom_Pdg"]
array1= mom_Pdg.array()
h = hist.Hist(hist.axis.Regular(10, 0, 100, label="mom Pdg"))
h.fill(array1)
h.plot()
# Out:
# [StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x7ff4f6eaf1f0>, errorbar=<ErrorbarContainer object of 3 artists>, legend_artist=<ErrorbarContainer object of 3 artists>)]

# %%
mom_Mass = tree["mom_Mass"]
array1= mom_Mass.array()
h = hist.Hist(hist.axis.Regular(10, 0, 300, label="mom Mass"))
h.fill(array1)
h.plot()
# Out:
# [StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x7ff4f6d34a00>, errorbar=<ErrorbarContainer object of 3 artists>, legend_artist=<ErrorbarContainer object of 3 artists>)]

# %%
mom_Pt = tree["mom_Pt"]
array1= mom_Pt.array()
h = hist.Hist(hist.axis.Regular(90,0, 2000, label="mom Pt"))
h.fill(array1)
h.plot()
# Out:
# [StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x7ff4f2cf6c40>, errorbar=<ErrorbarContainer object of 3 artists>, legend_artist=<ErrorbarContainer object of 3 artists>)]

# %%
mom_Eta = tree["mom_Eta"]
array1= mom_Eta.array()
h = hist.Hist(hist.axis.Regular(40, 0, 200, label="mom Eta"))
h.fill(array1)
h.plot()
# Out:
# [StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x7ff4f694d700>, errorbar=<ErrorbarContainer object of 3 artists>, legend_artist=<ErrorbarContainer object of 3 artists>)]

# %%
mom_Phi = tree["mom_Phi"]
array1= mom_Phi.array()
h = hist.Hist(hist.axis.Regular(40, 0, 200, label="mom Phi"))
h.fill(array1)
h.plot()
# Out:
# [StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x7ff4f68c4dc0>, errorbar=<ErrorbarContainer object of 3 artists>, legend_artist=<ErrorbarContainer object of 3 artists>)]

# %%
momVis_Mass = tree["momVis_Mass"]
array1= momVis_Mass.array()
h = hist.Hist(hist.axis.Regular(100, 0,500, label="momVis Mass"))
h.fill(array1)
h.plot()
# Out:
# [StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x7ff4f66e9160>, errorbar=<ErrorbarContainer object of 3 artists>, legend_artist=<ErrorbarContainer object of 3 artists>)]

# %%
momVis_Pt = tree["momVis_Pt"]
array1= momVis_Pt.array()
h = hist.Hist(hist.axis.Regular(100, 0, 1000, label="momVis Pt"))
h.fill(array1)
h.plot()
# Out:
# [StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x7ff4f64ccb50>, errorbar=<ErrorbarContainer object of 3 artists>, legend_artist=<ErrorbarContainer object of 3 artists>)]

# %%
 momVis_Eta= tree["momVis_Eta"]
array1= momVis_Eta.array()
h = hist.Hist(hist.axis.Regular(40, 0, 1000, label="momVis Eta"))
h.fill(array1)
h.plot()
# Out:
# [StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x7ff4f63e6dc0>, errorbar=<ErrorbarContainer object of 3 artists>, legend_artist=<ErrorbarContainer object of 3 artists>)]

# %%
 momVis_Phi= tree["momVis_Phi"]
array1= momVis_Phi.array()
h = hist.Hist(hist.axis.Regular(40, 0, 1000, label="momVis Phi"))
h.fill(array1)
h.plot()
# Out:
# [StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x7ff4f6365f10>, errorbar=<ErrorbarContainer object of 3 artists>, legend_artist=<ErrorbarContainer object of 3 artists>)]

# %%
genTauPt_1 = tree["genTauPt_1"]
array1= genTauPt_1.array()
h = hist.Hist(hist.axis.Regular(100, 0, 2000, label="genTauPt 1"))
h.fill(array1)
h.plot()
# Out:
# [StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x7ff4f62687c0>, errorbar=<ErrorbarContainer object of 3 artists>, legend_artist=<ErrorbarContainer object of 3 artists>)]

# %%
genTauEta_1 = tree["genTauEta_1"]
array1= genTauEta_1.array()
h = hist.Hist(hist.axis.Regular(40, 0, 1000, label="genTauEta 1"))
h.fill(array1)
h.plot()
# Out:
# [StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x7ff4f6191c70>, errorbar=<ErrorbarContainer object of 3 artists>, legend_artist=<ErrorbarContainer object of 3 artists>)]

# %%
genTauPhi_1 = tree["genTauPhi_1"]
array1= genTauPhi_1.array()
h = hist.Hist(hist.axis.Regular(40, 0, 1000, label="genTauPhi 1"))
h.fill(array1)
h.plot()
# Out:
# [StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x7ff4f618a970>, errorbar=<ErrorbarContainer object of 3 artists>, legend_artist=<ErrorbarContainer object of 3 artists>)]

# %%
genTauM_1 = tree["genTauM_1"]
array1= genTauM_1.array()
h = hist.Hist(hist.axis.Regular(40, 0, 1000, label="genTauM 1"))
h.fill(array1)
h.plot()
# Out:
# [StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x7ff4f60f7df0>, errorbar=<ErrorbarContainer object of 3 artists>, legend_artist=<ErrorbarContainer object of 3 artists>)]

# %%
genTauPt_2 = tree["genTauPt_2"]
array1= genTauPt_2.array()
h = hist.Hist(hist.axis.Regular(100, 0, 1000, label="genTauPt 2"))
h.fill(array1)
h.plot()
# Out:
# [StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x7ff4f6004d90>, errorbar=<ErrorbarContainer object of 3 artists>, legend_artist=<ErrorbarContainer object of 3 artists>)]

# %%
genTauEta_2 = tree["genTauEta_2"]
array1= genTauEta_2.array()
h = hist.Hist(hist.axis.Regular(40, 0, 1000, label="genTauEta 2"))
h.fill(array1)
h.plot()
# Out:
# [StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x7ff4f5f25670>, errorbar=<ErrorbarContainer object of 3 artists>, legend_artist=<ErrorbarContainer object of 3 artists>)]

# %%
genTauPhi_2 = tree["genTauPhi_2"]
array1= genTauPhi_2.array()
h = hist.Hist(hist.axis.Regular(40, 0, 1000, label="genTauPhi 2"))
h.fill(array1)
h.plot()
# Out:
# [StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x7ff4f5eab910>, errorbar=<ErrorbarContainer object of 3 artists>, legend_artist=<ErrorbarContainer object of 3 artists>)]

# %%
genTauM_2 = tree["genTauM_2"]
array1= genTauM_2.array()
h = hist.Hist(hist.axis.Regular(40, 0, 1000, label="genTauM 2"))
h.fill(array1)
h.plot()
# Out:
# [StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x7ff4f5e30c40>, errorbar=<ErrorbarContainer object of 3 artists>, legend_artist=<ErrorbarContainer object of 3 artists>)]

# %%
genTauLegDR = tree["genTauLegDR"]
array1= genTauLegDR.array()
h = hist.Hist(hist.axis.Regular(20, 0, 1000, label="genTauLeg DR"))
h.fill(array1)
h.plot()
# Out:
# [StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x7ff4f5c6c040>, errorbar=<ErrorbarContainer object of 3 artists>, legend_artist=<ErrorbarContainer object of 3 artists>)]

# %%
genPt_1 = tree["genPt_1"]
array1= genPt_1.array()
h = hist.Hist(hist.axis.Regular(100, 0, 1000, label="genPt 1"))
h.fill(array1)
h.plot()
# Out:
# [StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x7ff4f5b010a0>, errorbar=<ErrorbarContainer object of 3 artists>, legend_artist=<ErrorbarContainer object of 3 artists>)]

# %%
genEta_1 = tree["genEta_1"]
array1= genEta_1.array()
h = hist.Hist(hist.axis.Regular(40, 0, 1000, label="genEta 1"))
h.fill(array1)
h.plot()
# Out:
# [StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x7ff4f5a192e0>, errorbar=<ErrorbarContainer object of 3 artists>, legend_artist=<ErrorbarContainer object of 3 artists>)]

# %%
 genPhi_1= tree["genPhi_1"]
array1= genPhi_1.array()
h = hist.Hist(hist.axis.Regular(40, 0, 1000, label="genPhi 1"))
h.fill(array1)
h.plot()
# Out:
# [StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x7ff4f5996430>, errorbar=<ErrorbarContainer object of 3 artists>, legend_artist=<ErrorbarContainer object of 3 artists>)]

# %%
genM_1 = tree["genM_1"]
array1= genM_1.array()
h = hist.Hist(hist.axis.Regular(40, 0, 1000, label="genM 1"))
h.fill(array1)
h.plot()
# Out:
# [StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x7ff4f59125e0>, errorbar=<ErrorbarContainer object of 3 artists>, legend_artist=<ErrorbarContainer object of 3 artists>)]

# %%
genPdg_1 = tree["genPdg_1"]
array1= genPdg_1.array()
h = hist.Hist(hist.axis.Regular(40, 0, 1000, label="genPdg 1"))
h.fill(array1)
h.plot()
# Out:
# [StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x7ff4f58968b0>, errorbar=<ErrorbarContainer object of 3 artists>, legend_artist=<ErrorbarContainer object of 3 artists>)]

# %%
genPt_2 = tree["genPt_2"]
array1= genPt_2.array()
h = hist.Hist(hist.axis.Regular(100, 0, 400, label="genPt 2"))
h.fill(array1)
h.plot()
# Out:
# [StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x7ff4f5659580>, errorbar=<ErrorbarContainer object of 3 artists>, legend_artist=<ErrorbarContainer object of 3 artists>)]

# %%
genEta_2 = tree["genEta_2"]
array1= genEta_2.array()
h = hist.Hist(hist.axis.Regular(40, 0, 1000, label="genEta 2"))
h.fill(array1)
h.plot()
# Out:
# [StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x7ff4f55ff490>, errorbar=<ErrorbarContainer object of 3 artists>, legend_artist=<ErrorbarContainer object of 3 artists>)]

# %%
 genPhi_2= tree["genPhi_2"]
array1= genPhi_2.array()
h = hist.Hist(hist.axis.Regular(40, 0, 1000, label="genPhi 2"))
h.fill(array1)
h.plot()
# Out:
# [StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x7ff4f55796a0>, errorbar=<ErrorbarContainer object of 3 artists>, legend_artist=<ErrorbarContainer object of 3 artists>)]

# %%
genM_2 = tree["genM_2"]
array1= genM_2.array()
h = hist.Hist(hist.axis.Regular(40, 0, 1000, label="genM 2"))
h.fill(array1)
h.plot()
# Out:
# [StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x7ff4f54f9700>, errorbar=<ErrorbarContainer object of 3 artists>, legend_artist=<ErrorbarContainer object of 3 artists>)]

# %%
 genPdg_2= tree["genPdg_2"]
array1= genPdg_2.array()
h = hist.Hist(hist.axis.Regular(40, 0, 1000, label="genPdg 2"))
h.fill(array1)
h.plot()
# Out:
# [StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x7ff4f547bc10>, errorbar=<ErrorbarContainer object of 3 artists>, legend_artist=<ErrorbarContainer object of 3 artists>)]

# %%
genLegDR = tree["genLegDR"]
array1= genLegDR.array()
h = hist.Hist(hist.axis.Regular(40, 0, 1000, label="genLeg DR"))
h.fill(array1)
h.plot()
# Out:
# [StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x7ff4f5401ee0>, errorbar=<ErrorbarContainer object of 3 artists>, legend_artist=<ErrorbarContainer object of 3 artists>)]

# %%
genLegDEta = tree["genLegDEta"]
array1= genLegDEta.array()
h = hist.Hist(hist.axis.Regular(40, 0, 1000, label="genLeg D Eta"))
h.fill(array1)
h.plot()
# Out:
# [StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x7ff4f5313220>, errorbar=<ErrorbarContainer object of 3 artists>, legend_artist=<ErrorbarContainer object of 3 artists>)]

# %%
genLegDPhi = tree["genLegDPhi"]
array1= genLegDPhi.array()
h = hist.Hist(hist.axis.Regular(40, 0, 1000, label="genLeg D Phi"))
h.fill(array1)
h.plot()
# Out:
# [StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x7ff4f52984c0>, errorbar=<ErrorbarContainer object of 3 artists>, legend_artist=<ErrorbarContainer object of 3 artists>)]

# %%
nTauE = tree["nTauE"]
array1= nTauE.array()
h = hist.Hist(hist.axis.Regular(40, 0, 1000, label="nTau E"))
h.fill(array1)
h.plot()
# Out:
# [StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x7ff4f521b790>, errorbar=<ErrorbarContainer object of 3 artists>, legend_artist=<ErrorbarContainer object of 3 artists>)]

# %%
 nTauMu= tree["nTauMu"]
array1= nTauMu.array()
h = hist.Hist(hist.axis.Regular(40, 0, 1000, label="nTauMu"))
h.fill(array1)
h.plot()
# Out:
# [StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x7ff4f519fa00>, errorbar=<ErrorbarContainer object of 3 artists>, legend_artist=<ErrorbarContainer object of 3 artists>)]

# %%
nTauH = tree["nTauH"]
array1= nTauH.array()
h = hist.Hist(hist.axis.Regular(40, 0, 1000, label="nTau H"))
h.fill(array1)
h.plot()
# Out:
# [StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x7ff4f5126df0>, errorbar=<ErrorbarContainer object of 3 artists>, legend_artist=<ErrorbarContainer object of 3 artists>)]

# %%
nGenCandsFound = tree["nGenCandsFound"]
array1= nGenCandsFound.array()
h = hist.Hist(hist.axis.Regular(40, 0, 1000, label="nGenCands Found"))
h.fill(array1)
h.plot()
# Out:
# [StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x7ff4f50bb0d0>, errorbar=<ErrorbarContainer object of 3 artists>, legend_artist=<ErrorbarContainer object of 3 artists>)]

# %%
 recoPt_1= tree["recoPt_1"]
array1= recoPt_1.array()
h = hist.Hist(hist.axis.Regular(50, 0, 500, label="recoPt 1"))
h.fill(array1)
h.plot()
# Out:
# [StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x7ff4f4ed88e0>, errorbar=<ErrorbarContainer object of 3 artists>, legend_artist=<ErrorbarContainer object of 3 artists>)]

# %%
recoPt_2 = tree["recoPt_2"]
array1= recoPt_2.array()
h = hist.Hist(hist.axis.Regular(50, 0, 400, label="recoPt 2"))
h.fill(array1)
h.plot()
# Out:
# [StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x7ff4f4d740d0>, errorbar=<ErrorbarContainer object of 3 artists>, legend_artist=<ErrorbarContainer object of 3 artists>)]

# %%
 recoEta_1= tree["recoEta_1"]
array1= recoEta_1.array()
h = hist.Hist(hist.axis.Regular(40, 0, 1000, label="recoEta 1"))
h.fill(array1)
h.plot()
# Out:
# [StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x7ff4f4d05160>, errorbar=<ErrorbarContainer object of 3 artists>, legend_artist=<ErrorbarContainer object of 3 artists>)]

# %%
 recoEta_2= tree["recoEta_2"]
array1= recoEta_2.array()
h = hist.Hist(hist.axis.Regular(40, 0, 1000, label="recoEta 2"))
h.fill(array1)
h.plot()
# Out:
# [StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x7ff4f4c869d0>, errorbar=<ErrorbarContainer object of 3 artists>, legend_artist=<ErrorbarContainer object of 3 artists>)]

# %%
 recoPhi_1= tree["recoPhi_1"]
array1= recoPhi_1.array()
h = hist.Hist(hist.axis.Regular(40, 0, 1000, label="recoPhi 1"))
h.fill(array1)
h.plot()
# Out:
# [StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x7ff4f4b98310>, errorbar=<ErrorbarContainer object of 3 artists>, legend_artist=<ErrorbarContainer object of 3 artists>)]

# %%
 recoPhi_2= tree["recoPhi_2"]
array1= recoPhi_2.array()
h = hist.Hist(hist.axis.Regular(40, 0, 1000, label="recoPhi 2"))
h.fill(array1)
h.plot()
# Out:
# [StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x7ff4f4b17bb0>, errorbar=<ErrorbarContainer object of 3 artists>, legend_artist=<ErrorbarContainer object of 3 artists>)]

# %%
recoM_1 = tree["recoM_1"]
array1= recoM_1.array()
h = hist.Hist(hist.axis.Regular(40, 0, 1000, label="recoM 1"))
h.fill(array1)
h.plot()
# Out:
# [StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x7ff4f4aa4130>, errorbar=<ErrorbarContainer object of 3 artists>, legend_artist=<ErrorbarContainer object of 3 artists>)]

# %%
recoM_2 = tree["recoM_2"]
array1= recoM_2.array()
h = hist.Hist(hist.axis.Regular(40, 0, 1000, label="recoM 2"))
h.fill(array1)
h.plot()
# Out:
# [StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x7ff4f4a18640>, errorbar=<ErrorbarContainer object of 3 artists>, legend_artist=<ErrorbarContainer object of 3 artists>)]

# %%
recoDiCandPt = tree["recoDiCandPt"]
array1= recoDiCandPt.array()
h = hist.Hist(hist.axis.Regular(40, 0, 600, label="recoDiCandPt"))
h.fill(array1)
h.plot()
# Out:
# [StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x7ff4f4918790>, errorbar=<ErrorbarContainer object of 3 artists>, legend_artist=<ErrorbarContainer object of 3 artists>)]

# %%
 recoDiCandM= tree["recoDiCandM"]
array1= recoDiCandM.array()
h = hist.Hist(hist.axis.Regular(50, 0, 1000, label="recoDiCandM"))
h.fill(array1)
h.plot()
# Out:
# [StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x7ff4f48236a0>, errorbar=<ErrorbarContainer object of 3 artists>, legend_artist=<ErrorbarContainer object of 3 artists>)]

# %%
recoDR = tree["recoDR"]
array1= recoDR.array()
h = hist.Hist(hist.axis.Regular(20, 0, 500, label="recoDR"))
h.fill(array1)
h.plot()
# Out:
# [StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x7ff4f46a78b0>, errorbar=<ErrorbarContainer object of 3 artists>, legend_artist=<ErrorbarContainer object of 3 artists>)]

# %%
recoDEta = tree["recoDEta"]
array1= recoDEta.array()
h = hist.Hist(hist.axis.Regular(20, 0,500, label="recoDEta"))
h.fill(array1)
h.plot()
# Out:
# [StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x7ff4f4528af0>, errorbar=<ErrorbarContainer object of 3 artists>, legend_artist=<ErrorbarContainer object of 3 artists>)]

# %%
 recoDPhi= tree["recoDPhi"]
array1= recoDPhi.array()
h = hist.Hist(hist.axis.Regular(40, 0, 1000, label="recoDPhi"))
h.fill(array1)
h.plot()
# Out:
# [StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x7ff4f44aa430>, errorbar=<ErrorbarContainer object of 3 artists>, legend_artist=<ErrorbarContainer object of 3 artists>)]

# %%
l1Pt = tree["l1Pt"]
array1= l1Pt.array()
h = hist.Hist(hist.axis.Regular(40, 0, 600, label="l1Pt"))
h.fill(array1)
h.plot()
# Out:
# [StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x7ff4f43b01c0>, errorbar=<ErrorbarContainer object of 3 artists>, legend_artist=<ErrorbarContainer object of 3 artists>)]

# %%
l1Eta = tree["l1Eta"]
array1= l1Eta.array()
h = hist.Hist(hist.axis.Regular(40, 0, 200, label="l1Eta"))
h.fill(array1)
h.plot()
# Out:
# [StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x7ff4f42a7eb0>, errorbar=<ErrorbarContainer object of 3 artists>, legend_artist=<ErrorbarContainer object of 3 artists>)]

# %%
l1Phi = tree["l1Phi"]
array1= l1Phi.array()
h = hist.Hist(hist.axis.Regular(40, 0, 1000, label="l1Phi"))
h.fill(array1)
h.plot()
# Out:
# [StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x7ff4f4236730>, errorbar=<ErrorbarContainer object of 3 artists>, legend_artist=<ErrorbarContainer object of 3 artists>)]

# %%
 l1BoostedPt= tree["l1BoostedPt"]
array1= l1BoostedPt.array()
h = hist.Hist(hist.axis.Regular(50, 0, 700, label="l1BoostedPt"))
h.fill(array1)
h.plot()
# Out:
# [StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x7ff4f40405e0>, errorbar=<ErrorbarContainer object of 3 artists>, legend_artist=<ErrorbarContainer object of 3 artists>)]

# %%
l1BoostedEta = tree["l1BoostedEta"]
array1= l1BoostedEta.array()
h = hist.Hist(hist.axis.Regular(40, 0, 1000, label="l1BoostedEta"))
h.fill(array1)
h.plot()
# Out:
# [StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x7ff4f3fc7a00>, errorbar=<ErrorbarContainer object of 3 artists>, legend_artist=<ErrorbarContainer object of 3 artists>)]

# %%
l1BoostedPhi = tree["l1BoostedPhi"]
array1= l1BoostedPhi.array()
h = hist.Hist(hist.axis.Regular(40, 0, 1000, label="l1BoostedPhi"))
h.fill(array1)
h.plot()
# Out:
# [StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x7ff4f3ed4130>, errorbar=<ErrorbarContainer object of 3 artists>, legend_artist=<ErrorbarContainer object of 3 artists>)]

# %%
i=0
for i in range(len(tree)):
    aspect = tree[i]
    array1 = aspect.array()
    h = hist.Hist(hist.axis.Regular(50, 0, 600, label="Graph Compilation"))
    h.fill(array1)
    h.plot()
